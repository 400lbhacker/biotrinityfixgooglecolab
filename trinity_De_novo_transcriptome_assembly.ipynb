# %%
import os
# !sudo apt-get update
# !sudo apt-get install samtools
# !echo 'export PATH=/path/to/samtools:$PATH' >> ~/.bashrc
# !source ~/.bashrc

# !apt-get install -y build-essential
# !apt-get install -y zlib1g-dev
# !apt-get install -y perl
# !apt-get install -y cmake
# !apt-get install -y cpanminus
# !apt-get install -y sra-toolkit
# !vdb-config -v
# !cpanm install URI::Escape
# !apt-get install -y jellyfish
# !apt-get install -y bowtie2
# !pip install -y salmon

# !rm /usr/local/lib/python3.10/dist-packages/logan/importer.py
# !rm /usr/local/lib/python3.10/dist-packages/logan/runner.py

# !wget -O importer.py https://github.com/400lbhacker/biotrinityfixgooglecolab/raw/main/importer.py
# !mv importer.py /usr/local/lib/python3.10/dist-packages/logan/importer.py

# !wget -O importer.py https://github.com/400lbhacker/biotrinityfixgooglecolab/raw/main/runner.py
# !mv importer.py /usr/local/lib/python3.10/dist-packages/logan/runner.py

os.environ['PATH'] += ":/usr/bin/bowtie2"


# Download and install Trinity
# !wget https://github.com/trinityrnaseq/trinityrnaseq/releases/download/v2.12.0/trinityrnaseq-v2.12.0.FULL.tar.gz
# !tar -xzvf trinityrnaseq-v2.12.0.FULL.tar.gz
# !rm trinityrnaseq-v2.12.0.FULL.tar.gz
# !mv trinityrnaseq-v2.12.0/ /usr/local/
# !echo 'export PATH="/usr/local/trinityrnaseq-v2.12.0:$PATH"' >> ~/.bashrc
# !source ~/.bashrc

# Verify Trinity installation
# !which Trinity

os.chdir('/usr/local/trinityrnaseq-v2.12.0/')
# !make

# !samtools --version
# !bowtie2 --version
# !salmon --version

# !rm Trinity
# !wget -O Trinity https://github.com/400lbhacker/biotrinityfixgooglecolab/blob/main/Trinity
#!mv Trinity /usr/local/lib/python3.10/dist-packages/logan/runner.py

# !/usr/local/trinityrnaseq-v2.12.0/Trinity
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [915 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,185 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [995 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,015 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,251 kB]
# ...

# %%
# !apt-get install seqtk
# !samtools faidx /content/sequence.fasta
# !wgsim -N 10000 -1 150 -2 150 /content/sequence.fasta /content/left.fq /content/right.fq

# !seqtk seq -Q64 -V -s 100 /content/left.fq > /content/left_with_qual.fq
# !seqtk seq -Q64 -V -s 100 /content/right.fq > /content/right_with_qual.fq
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   seqtk
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 30.2 kB of archives.
# After this operation, 85.0 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 seqtk amd64 1.3-2 [30.2 kB]
# Fetched 30.2 kB in 0s (115 kB/s)
# Selecting previously unselected package seqtk.
# (Reading database ... 122529 files and directories currently installed.)
# Preparing to unpack .../archives/seqtk_1.3-2_amd64.deb ...
# Unpacking seqtk (1.3-2) ...
# Setting up seqtk (1.3-2) ...
# Processing triggers for man-db (2.10.2-1) ...
# [wgsim] seed = 1693701033
# [wgsim_core] calculating the total length of the reference sequence...
# [wgsim_core] 1 sequences, total length: 113064
# gi|902687128|ref|NC_027618.1|	56	C	M	+
# gi|902687128|ref|NC_027618.1|	1488	C	Y	+
# ...

# %%
# !mkdir /content/my_trinity_output

# !/usr/local/trinityrnaseq-v2.12.0/Trinity --seqType fq --left /content/left.fq --right /content/right.fq --max_memory 10G --CPU 2 --output /content/my_trinity_output

#!/content/trinityrnaseq-v2.15.1/Trinity --seqType fq --single /content/sequence.fasta --max_memory 10G --CPU 2 --output trinity_output

# !zip -r /content/archive_name.zip /content/my_trinity_output
# Out:
# mkdir: cannot create directory ‘/content/my_trinity_output’: File exists
#
#
#      ______  ____   ____  ____   ____  ______  __ __
#     |      ||    \ |    ||    \ |    ||      ||  |  |
#     |      ||  D  ) |  | |  _  | |  | |      ||  |  |
#     |_|  |_||    /  |  | |  |  | |  | |_|  |_||  ~  |
#       |  |  |    \  |  | |  |  | |  |   |  |  |___, |
#       |  |  |  .  \ |  | |  |  | |  |   |  |  |     |
#       |__|  |__|\_||____||__|__||____|  |__|  |____/
#
#     Trinity-v2.12.0
#
#
#
# Left read files: $VAR1 = [
#           '/content/left.fq'
#         ];
# Right read files: $VAR1 = [
#           '/content/right.fq'
#         ];
# Trinity version: Trinity-v2.12.0
# ** NOTE: Latest version of Trinity is Trinity-v2.15.1, and can be obtained at:
# 	https://github.com/trinityrnaseq/trinityrnaseq/releases
#
# Sunday, September 3, 2023: 00:34:52	CMD: java -Xmx64m -XX:ParallelGCThreads=2  -jar /usr/local/trinityrnaseq-v2.12.0/util/support_scripts/ExitTester.jar 0
# ...
